# %% [markdown]
# # Task 4: Analysis
# ### Research Question:
# Based on 1994 census data (adult data) collected in the United States, are there any trends or patterns when comparing Education Level, Race, and Sex to Income level?
# In the case of this data analysis income is categorized into two options: (1) having an income equal to or under 50000 US dollars per year or (2) having an income of over 50000 US dollars per year.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling as pf
sns.despine()
sns.set(font_scale=1)

# %% [markdown]
# # Profile Report of the Adult Data

# %%
from scripts import project_functions 
df = project_functions.load_and_process('../data/raw/adult.data')
import pandas_profiling as pf
PR_df = pf.ProfileReport(df)
PR_df
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-08-11 19:31:01.002257&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Summary of Profile Report
# ### Trends in Variables
# - Majority of individuals have a highschool education followed by those with Some-college
# - Data represents information from more than 2x the amount of males than females
# - Mean age of 38, which sense since people would be working age and typically retire at 65 years of age
# - Most work in the private sector
# - There were five race options: White, Black, Asian Pacific Islander, American Indian Eskimo, and Other. Of the Races, most identified as white (over 27000) followed by Black(312). Majority of this sample is White.
#
# ### Correlation Matrix (with only categorical variables)
#
# - No correlation between race/native-country and income. But some correlation between Native-Country and Education Level
# - Small correlation between Income and Sex
# - Correlation between Income and Education Level
# - Correlation between Income and both Education level and Sex
#
# ### Comments
# The small number of females and Black Americans to participate in this census should be noted. Although the numbers could represent the proportion of these demographics in the United States, it's also important to consider the distribution of the census and those who are more likely to participate in the census. Both of these factors could skew the data. For example, socioeconomic factors such as working class, education level, and income could skew who had the means to participated in this census.

# %% [markdown]
# # Comparing the categorical variables Sex, Race, and Education Level with Income based on Final Weight

# %% [markdown]
# ### Education, Sex, and Income
#
# In the bar graph below "Income based on Education Level" it appears that there is a pattern of making equal to or under 50,000 US dollars per year, if you have an education level of highschool or lower. In contrast, individuals with an education level of some college or greater are more likely to have an income of over 50,000 US dollars per year.

# %%
plt.figure(figsize=(15,8))
ax_Ed_Sex = sns.barplot(x="Education Level", y='Final Weight', hue='Income', data=df,).set_title('Figure 1: Income based on Education Level')
plt.show()

# %% [markdown]
# Since there are some trends when considering an individuals anual income based on their education, lets see which sex is more likely to have particular levels of education. Let's consider the violin plot and bar plot below.

# %%
plt.figure(figsize=(10,10))
sns.violinplot(data=df, x="Final Weight", y="Education Level", hue="Sex", orient='h',
               split=True).set_title('Income based on Education level and Sex')
sns.despine(left=True)

# %%
plt.figure(figsize=(15,8))
ax_Ed_Sex = sns.barplot(x="Education Level", y='Final Weight', hue='Sex', data=df,).set_title('Education Level Organized by Sex')
plt.show()

# %% [markdown]
# The barplot and violin plot above show that overall males are more likely than females to have higher education levels based on a final weighted score. Although, it's important to note that the differences are small for males and females with a highschool diploma and masters. It's also important to note that females are more likely to have a doctorate than males. Although there are some differences in education among males and females, let's refer back to our research question and and focus on whether or not there differences are in regards to their income. See figure bellow.

# %%
plt.figure(figsize=(8,4))
ax_Ed_Sex = sns.barplot(x="Income", y='Final Weight', hue='Sex', data=df,).set_title('Income Organized by Sex')
plt.show()

# %% [markdown]
# In the figure above males are more likely to make both under or equal to 50K and over 50K. Based on the graph above as well as the graph showing  "Education Level Organized by Sex" it would appear that the slight differences in education level among males and females could correlate with males being more likely to make 50K, while also explaining the larger proportion of males with lower education levels being more likely to make under 50k.
#
# ### Relationships between Race, Education, and Income
# Now let's look as some trends in regards to race and income. Consider the bar plot below.

# %%
plt.figure(figsize=(15,10))
ax_Ed_Sex = sns.barplot(x="Income", y='Final Weight', hue='Race', data=df,).set_title('Income based on Race by Final Weight')
plt.show()

# %% [markdown]
# The bar plot above is categorized by income level based on race. As you can see Black Americans are most likely to make under 50,000 dollars, but also most likely to make over 50 000 dollars based on their final weighted score. It is important to note that there was a very small sample of Black Americans (312 individuals) to participate in this census, whereas there were over 20000 White americans; this suggests that the actual number of Black Americans with an income of over 50K is very small.
#
# Consider the graph below that shows the number of individuals and their income based on race.

# %%
ax_income = sns.countplot(y="Race", hue='Income', data=df,).set_title('Income based on Race by Number')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Now let's look at the next graph and consider whether or not education level could also be a contributing factor when considering income based on race.

# %%
plt.figure(figsize=(15,8))
ax_Ed_Sex = sns.barplot(x="Education Level", y='Final Weight', hue='Race', data=df,).set_title('Income based on Race')
plt.show()

# %% [markdown]
# In the graph above, you can see that Black Americans are more likely than other races to have the education level in all categories except a doctorate, prof-school, elementary, or preschool. White americans are most likely to have their doctorate, followed by Asian Pacific Islanders. American Indian Eskimo's are most likely to have there education in a prof-school and least likely to have their doctorate.

# %% [markdown]
# # Conclusion
# There were some patterns in the Adult Census data when considering the variables sex, race, and education level based on income. By comparing the the barplots "Education Level Organized by Sex" and "Income Based on Sex" we can see that education level and income could be positively correlated, because american males were more slightly more likely to have a higher education level and make over 50K than american females.
#
# We also used barplots to compared and visualized relationships betewee race, education level, and income. As we could see in the barplot "Income Based on Race by Final Weight", Black Americans were most likely to make both over and under 50k based on their final weighted score, however, the actual number of Black americans to make over 50K was very small when compared to white americans in the countplot "Income Based on Race by Count". When the variable education level was also considered Black Americans were most likely to have the an education level in most categories except less likely than both white americans and Asian Pacific Islanders to have their doctorate.
#
# Overall, the demographics with higher education levels (white males) were also more likely to have an income of over 50,000 US dollars per year. Further data analysis to see the degree of these relationships and strengths of the correlations should be conducted
