# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/raw/1310076501_databaseLoadingData.csv")
data
# Out:
#      REF_DATE     GEO           DGUID             Age group         Sex  \
# 0        2019  Canada  2011A000011124  Total, 5 to 17 years  Both sexes
# 1        2019  Canada  2011A000011124  Total, 5 to 17 years  Both sexes
# 2        2019  Canada  2011A000011124  Total, 5 to 17 years  Both sexes
# 3        2019  Canada  2011A000011124  Total, 5 to 17 years  Both sexes
# 4        2019  Canada  2011A000011124  Total, 5 to 17 years  Both sexes
# ..        ...     ...             ...                   ...         ...
# 247      2019  Canada  2011A000011124        12 to 17 years     Females
# 248      2019  Canada  2011A000011124        12 to 17 years     Females
# 249      2019  Canada  2011A000011124        12 to 17 years     Females
# 250      2019  Canada  2011A000011124        12 to 17 years     Females
# 251      2019  Canada  2011A000011124        12 to 17 years     Females
#
#                                             Domains    Characteristics  \
# 0                                            Seeing  Number of persons
# 1                                            Seeing            Percent
# 2                                           Hearing  Number of persons
# 3                                           Hearing            Percent
# 4                                           Walking  Number of persons
# ..                                              ...                ...
# 247                                         Anxiety            Percent
# 248                                      Depression  Number of persons
# 249                                      Depression            Percent
# 250  Functional difficulties in at least one domain  Number of persons
# 251  Functional difficulties in at least one domain            Percent
#
#          UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  \
# 0     Number     223         units          0  v1200113301   1.1.1.1.1
# 1    Percent     239         units          0  v1200113304   1.1.1.1.4
# 2     Number     223         units          0  v1200113307   1.1.1.2.1
# 3    Percent     239         units          0  v1200113310   1.1.1.2.4
# 4     Number     223         units          0  v1200113313   1.1.1.3.1
# ..       ...     ...           ...        ...          ...         ...
# 247  Percent     239         units          0  v1200114042  1.3.3.12.4
# 248   Number     223         units          0  v1200114045  1.3.3.13.1
# 249  Percent     239         units          0  v1200114048  1.3.3.13.4
# 250   Number     223         units          0  v1200114051  1.3.3.14.1
# 251  Percent     239         units          0  v1200114054  1.3.3.14.4
#
#          VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0     27100.00    NaN     NaN         NaN         0
# 1         0.54    NaN     NaN         NaN         2
# 2      8500.00    NaN     NaN         NaN         0
# 3         0.17    NaN     NaN         NaN         2
# 4     47000.00    NaN     NaN         NaN         0
# ..         ...    ...     ...         ...       ...
# 247       7.20    NaN     NaN         NaN         2
# 248   22100.00    NaN     NaN         NaN         0
# 249       1.98    NaN     NaN         NaN         2
# 250  141900.00    NaN     NaN         NaN         0
# 251      12.80    NaN     NaN         NaN         2
#
# [252 rows x 18 columns]

# %%
data.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Age group', 'Sex', 'Domains',
#        'Characteristics', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID',
#        'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED',
#        'DECIMALS'],
#       dtype='object')

# %%
data_col_clean = data.drop(['REF_DATE', "GEO", "DGUID", "UOM_ID", "SCALAR_FACTOR", "SCALAR_ID", "VECTOR", "COORDINATE", "STATUS", "SYMBOL", 'TERMINATED', 'DECIMALS'], axis=1)
#deleted multiple columns

# %%
data_col_clean
# Out:
#                 Age group         Sex  \
# 0    Total, 5 to 17 years  Both sexes
# 1    Total, 5 to 17 years  Both sexes
# 2    Total, 5 to 17 years  Both sexes
# 3    Total, 5 to 17 years  Both sexes
# 4    Total, 5 to 17 years  Both sexes
# ..                    ...         ...
# 247        12 to 17 years     Females
# 248        12 to 17 years     Females
# 249        12 to 17 years     Females
# 250        12 to 17 years     Females
# 251        12 to 17 years     Females
#
#                                             Domains    Characteristics  \
# 0                                            Seeing  Number of persons
# 1                                            Seeing            Percent
# 2                                           Hearing  Number of persons
# 3                                           Hearing            Percent
# 4                                           Walking  Number of persons
# ..                                              ...                ...
# 247                                         Anxiety            Percent
# 248                                      Depression  Number of persons
# 249                                      Depression            Percent
# 250  Functional difficulties in at least one domain  Number of persons
# 251  Functional difficulties in at least one domain            Percent
#
#          UOM      VALUE
# 0     Number   27100.00
# 1    Percent       0.54
# 2     Number    8500.00
# 3    Percent       0.17
# 4     Number   47000.00
# ..       ...        ...
# 247  Percent       7.20
# 248   Number   22100.00
# 249  Percent       1.98
# 250   Number  141900.00
# 251  Percent      12.80
#
# [252 rows x 6 columns]

# %%
data_columnscleaned['Age group'].value_counts() #shows 3 categories, 84 total --consider removing rows of totals
# Out:
# Total, 5 to 17 years    84
# 5 to 11 years           84
# 12 to 17 years          84
# Name: Age group, dtype: int64

# %%
sorted(list(data.columns))
# Out:
# ['Age group',
#  'COORDINATE',
#  'Characteristics',
#  'DECIMALS',
#  'DGUID',
#  'Domains',
#  'GEO',
#  'REF_DATE',
#  'SCALAR_FACTOR',
#  'SCALAR_ID',
#  'STATUS',
#  'SYMBOL',
#  'Sex',
#  'TERMINATED',
#  'UOM',
#  'UOM_ID',
#  'VALUE',
#  'VECTOR']

# %%
# n_by_state = df.groupby("state")["last_name"].count()
# n_by_state.head(10)

# %%
data_columnscleaned.shape
# Out:
# (252, 7)

# %%
data_columnscleaned.describe()
# Out:
#               VALUE   DECIMALS
# count     250.00000  252.00000
# mean    31828.61300    1.00000
# std     70459.52072    1.00199
# min         0.12000    0.00000
# 25%         1.76250    0.00000
# 50%      1450.00000    1.00000
# 75%     32150.00000    2.00000
# max    657100.00000    2.00000

# %%
data.dtypes
# Out:
# REF_DATE             int64
# GEO                 object
# DGUID               object
# Age group           object
# Sex                 object
# Domains             object
# Characteristics     object
# UOM                 object
# UOM_ID               int64
# SCALAR_FACTOR       object
# SCALAR_ID            int64
# VECTOR              object
# COORDINATE          object
# VALUE              float64
# STATUS              object
# SYMBOL             float64
# TERMINATED         float64
# DECIMALS             int64
# dtype: object

# %%
data_columnscleaned.groupby('Domains').count() #suggested by prof to try out
#can see
# Out:
#                                                 Age group  Sex  \
# Domains
# Accepting change                                       18   18
# Anxiety                                                18   18
# Communication                                          18   18
# Concentrating                                          18   18
# Controlling behaviour                                  18   18
# Depression                                             18   18
# Functional difficulties in at least one domain         18   18
# Hearing                                                18   18
# Learning                                               18   18
# Making friends                                         18   18
# Remembering                                            18   18
# Seeing                                                 18   18
# Self-care                                              18   18
# Walking                                                18   18
#
#                                                 Characteristics  UOM  VALUE  \
# Domains
# Accepting change                                             18   18     18
# Anxiety                                                      18   18     18
# Communication                                                18   18     18
# Concentrating                                                18   18     18
# Controlling behaviour                                        18   18     18
# Depression                                                   18   18     18
# Functional difficulties in at least one domain               18   18     18
# Hearing                                                      18   18     16
# Learning                                                     18   18     18
# Making friends                                               18   18     18
# Remembering                                                  18   18     18
# Seeing                                                       18   18     18
# Self-care                                                    18   18     18
# Walking                                                      18   18     18
#
#                                                 DECIMALS
# Domains
# Accepting change                                      18
# Anxiety                                               18
# Communication                                         18
# Concentrating                                         18
# Controlling behaviour                                 18
# Depression                                            18
# Functional difficulties in at least one domain        18
# Hearing                                               18
# Learning                                              18
# Making friends                                        18
# Remembering                                           18
# Seeing                                                18
# Self-care                                             18
# Walking                                               18
